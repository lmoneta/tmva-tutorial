# %% [markdown]
# <img src="http://oproject.org/tiki-download_file.php?fileId=8&display&x=450&y=128">
# <img src="http://files.oproject.org/tmvalogo.png" height="50%" width="50%">
#
# # TMVA Classification Example Using a Convolutional Neural Network

# %% [markdown]
# ## Declare Factory
#
# Create the Factory class. Later you can choose the methods
# whose performance you'd like to investigate.
#
# The factory is the major TMVA object you have to interact with. Here is the list of parameters you need to pass
#
#  - The first argument is the base of the name of all the output
# weightfiles in the directory weight/ that will be created with the
# method parameters
#
#  - The second argument is the output file for the training results
#
#  - The third argument is a string option defining some general configuration for the TMVA session. For example all TMVA output can be suppressed by removing the "!" (not) in front of the "Silent" argument in the option string

# %%
import ROOT
from ROOT import TMVA
import os
# Out:
# Welcome to JupyROOT 6.15/01

# %%
ROOT.TMVA.Tools.Instance()
TMVA.PyMethodBase.PyInitialize()

## For PYMVA methods
TMVA.PyMethodBase.PyInitialize();


outputFile = ROOT.TFile.Open("CaloImages_ClassificationOutput.root", "RECREATE")

factory = ROOT.TMVA.Factory("TMVA_CaloImages_Classification", outputFile,
                      "!V:ROC:!Silent:Color:!DrawProgressBar:AnalysisType=Classification:!Correlations" )

# %% [markdown]
# ## Declare DataLoader(s)
#
# The next step is to declare the DataLoader class that deals with input variables
#
# Define the input variables that shall be used for the MVA training
# note that you may also use variable expressions, which can be parsed by TTree::Draw( "expression" )]
#
# In this case the input data consists of an image of 16x16 pixels. Each single pixel is a branch in a ROOT TTree

# %%
inputFileName = "CaloImages_data.root"

##inputFile = ROOT.TFile.Open( inputFileName )
ROOT.TFile.SetCacheFileDir(".");
inputWebFileName = "http://www.cern.ch/moneta/root/" + inputFileName
inputFile = ROOT.TFile.Open(inputWebFileName,"CACHEREAD")
inputFile.ls()
# Out:
# TFile**		./moneta/root/CaloImages_data.root
#  TFile*		./moneta/root/CaloImages_data.root
#   KEY: TTree	sig_tree;1	Signal Tree
#   KEY: TTree	bkg_tree;1	Background Tree
# Info in <TFile::OpenFromCache>: using local cache copy of http://www.cern.ch/moneta/root/CaloImages_data.root [./moneta/root/CaloImages_data.root]

# %%
# retrieve input trees

signalTree     = inputFile.Get("sig_tree")
backgroundTree = inputFile.Get("bkg_tree")

signalTree.Print()
# Out:
# ******************************************************************************
# *Tree    :sig_tree  : Signal Tree                                            *
# *Entries :    20000 : Total =        82781882 bytes  File  Size =    5752320 *
# *        :          : Tree compression factor =  14.29                       *
# ******************************************************************************
# *Br    0 :Energy0   : Energy0/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        484 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.22     *
# *............................................................................*
# *Br    1 :Energy1   : Energy1/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        479 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.60     *
# *............................................................................*
# *Br    2 :Energy2   : Energy2/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        476 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.45     *
# *............................................................................*
# *Br    3 :Energy3   : Energy3/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        462 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 138.52     *
# *............................................................................*
# *Br    4 :Energy4   : Energy4/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        462 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 138.52     *
# *............................................................................*
# *Br    5 :Energy5   : Energy5/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        469 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 136.45     *
# *............................................................................*
# *Br    6 :Energy6   : Energy6/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        472 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.58     *
# *............................................................................*
# *Br    7 :Energy7   : Energy7/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        528 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 121.20     *
# *............................................................................*
# *Br    8 :Energy8   : Energy8/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        499 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.25     *
# *............................................................................*
# *Br    9 :Energy9   : Energy9/F                                              *
# *Entries :    20000 : Total  Size=      80829 bytes  File Size  =        506 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 126.47     *
# *............................................................................*
# *Br   10 :Energy10  : Energy10/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        490 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.61     *
# *............................................................................*
# *Br   11 :Energy11  : Energy11/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   12 :Energy12  : Energy12/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        491 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.34     *
# *............................................................................*
# *Br   13 :Energy13  : Energy13/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   14 :Energy14  : Energy14/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   15 :Energy15  : Energy15/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        478 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.89     *
# *............................................................................*
# *Br   16 :Energy16  : Energy16/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   17 :Energy17  : Energy17/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        499 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.25     *
# *............................................................................*
# *Br   18 :Energy18  : Energy18/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.68     *
# *............................................................................*
# *Br   19 :Energy19  : Energy19/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        478 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.89     *
# *............................................................................*
# *Br   20 :Energy20  : Energy20/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        474 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.02     *
# *............................................................................*
# *Br   21 :Energy21  : Energy21/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        497 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.77     *
# *............................................................................*
# *Br   22 :Energy22  : Energy22/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   23 :Energy23  : Energy23/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   24 :Energy24  : Energy24/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        481 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.05     *
# *............................................................................*
# *Br   25 :Energy25  : Energy25/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   26 :Energy26  : Energy26/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        493 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.81     *
# *............................................................................*
# *Br   27 :Energy27  : Energy27/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        503 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 127.23     *
# *............................................................................*
# *Br   28 :Energy28  : Energy28/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   29 :Energy29  : Energy29/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        481 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.05     *
# *............................................................................*
# *Br   30 :Energy30  : Energy30/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        490 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.61     *
# *............................................................................*
# *Br   31 :Energy31  : Energy31/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        479 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.61     *
# *............................................................................*
# *Br   32 :Energy32  : Energy32/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        481 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.05     *
# *............................................................................*
# *Br   33 :Energy33  : Energy33/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        507 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 126.23     *
# *............................................................................*
# *Br   34 :Energy34  : Energy34/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   35 :Energy35  : Energy35/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.68     *
# *............................................................................*
# *Br   36 :Energy36  : Energy36/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        488 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.14     *
# *............................................................................*
# *Br   37 :Energy37  : Energy37/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   38 :Energy38  : Energy38/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        475 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.73     *
# *............................................................................*
# *Br   39 :Energy39  : Energy39/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   40 :Energy40  : Energy40/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        475 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.73     *
# *............................................................................*
# *Br   41 :Energy41  : Energy41/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   42 :Energy42  : Energy42/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        492 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.08     *
# *............................................................................*
# *Br   43 :Energy43  : Energy43/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        500 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.00     *
# *............................................................................*
# *Br   44 :Energy44  : Energy44/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        478 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.89     *
# *............................................................................*
# *Br   45 :Energy45  : Energy45/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   46 :Energy46  : Energy46/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   47 :Energy47  : Energy47/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        497 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.77     *
# *............................................................................*
# *Br   48 :Energy48  : Energy48/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        496 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.03     *
# *............................................................................*
# *Br   49 :Energy49  : Energy49/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   50 :Energy50  : Energy50/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        474 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.02     *
# *............................................................................*
# *Br   51 :Energy51  : Energy51/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        480 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.33     *
# *............................................................................*
# *Br   52 :Energy52  : Energy52/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   53 :Energy53  : Energy53/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        475 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.73     *
# *............................................................................*
# *Br   54 :Energy54  : Energy54/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        474 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.02     *
# *............................................................................*
# *Br   55 :Energy55  : Energy55/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        492 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.08     *
# *............................................................................*
# *Br   56 :Energy56  : Energy56/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   57 :Energy57  : Energy57/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        479 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.61     *
# *............................................................................*
# *Br   58 :Energy58  : Energy58/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        506 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 126.48     *
# *............................................................................*
# *Br   59 :Energy59  : Energy59/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        497 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.77     *
# *............................................................................*
# *Br   60 :Energy60  : Energy60/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   61 :Energy61  : Energy61/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.68     *
# *............................................................................*
# *Br   62 :Energy62  : Energy62/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   63 :Energy63  : Energy63/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        478 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.89     *
# *............................................................................*
# *Br   64 :Energy64  : Energy64/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        508 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 125.98     *
# *............................................................................*
# *Br   65 :Energy65  : Energy65/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   66 :Energy66  : Energy66/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        489 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.88     *
# *............................................................................*
# *Br   67 :Energy67  : Energy67/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   68 :Energy68  : Energy68/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   69 :Energy69  : Energy69/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.30     *
# *............................................................................*
# *Br   70 :Energy70  : Energy70/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        474 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.02     *
# *............................................................................*
# *Br   71 :Energy71  : Energy71/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        491 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.34     *
# *............................................................................*
# *Br   72 :Energy72  : Energy72/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        497 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.77     *
# *............................................................................*
# *Br   73 :Energy73  : Energy73/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        496 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.03     *
# *............................................................................*
# *Br   74 :Energy74  : Energy74/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        478 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.89     *
# *............................................................................*
# *Br   75 :Energy75  : Energy75/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   76 :Energy76  : Energy76/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        474 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.02     *
# *............................................................................*
# *Br   77 :Energy77  : Energy77/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        479 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.61     *
# *............................................................................*
# *Br   78 :Energy78  : Energy78/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.50     *
# *............................................................................*
# *Br   79 :Energy79  : Energy79/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        501 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 127.74     *
# *............................................................................*
# *Br   80 :Energy80  : Energy80/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   81 :Energy81  : Energy81/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        494 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.55     *
# *............................................................................*
# *Br   82 :Energy82  : Energy82/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   83 :Energy83  : Energy83/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   84 :Energy84  : Energy84/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        475 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.73     *
# *............................................................................*
# *Br   85 :Energy85  : Energy85/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        514 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 124.51     *
# *............................................................................*
# *Br   86 :Energy86  : Energy86/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   87 :Energy87  : Energy87/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        488 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.14     *
# *............................................................................*
# *Br   88 :Energy88  : Energy88/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br   89 :Energy89  : Energy89/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        480 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.33     *
# *............................................................................*
# *Br   90 :Energy90  : Energy90/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.68     *
# *............................................................................*
# *Br   91 :Energy91  : Energy91/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        488 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.14     *
# *............................................................................*
# *Br   92 :Energy92  : Energy92/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   93 :Energy93  : Energy93/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.78     *
# *............................................................................*
# *Br   94 :Energy94  : Energy94/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        492 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.08     *
# *............................................................................*
# *Br   95 :Energy95  : Energy95/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        492 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.08     *
# *............................................................................*
# *Br   96 :Energy96  : Energy96/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        464 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.93     *
# *............................................................................*
# *Br   97 :Energy97  : Energy97/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        474 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.02     *
# *............................................................................*
# *Br   98 :Energy98  : Energy98/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        491 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.34     *
# *............................................................................*
# *Br   99 :Energy99  : Energy99/F                                             *
# *Entries :    20000 : Total  Size=      80837 bytes  File Size  =        471 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.88     *
# *............................................................................*
# *Br  100 :Energy100 : Energy100/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  101 :Energy101 : Energy101/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        488 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.13     *
# *............................................................................*
# *Br  102 :Energy102 : Energy102/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        487 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.40     *
# *............................................................................*
# *Br  103 :Energy103 : Energy103/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  104 :Energy104 : Energy104/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.49     *
# *............................................................................*
# *Br  105 :Energy105 : Energy105/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        494 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.54     *
# *............................................................................*
# *Br  106 :Energy106 : Energy106/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        477 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.16     *
# *............................................................................*
# *Br  107 :Energy107 : Energy107/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  108 :Energy108 : Energy108/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.49     *
# *............................................................................*
# *Br  109 :Energy109 : Energy109/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        477 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.16     *
# *............................................................................*
# *Br  110 :Energy110 : Energy110/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        495 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.28     *
# *............................................................................*
# *Br  111 :Energy111 : Energy111/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        477 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.16     *
# *............................................................................*
# *Br  112 :Energy112 : Energy112/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        487 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.40     *
# *............................................................................*
# *Br  113 :Energy113 : Energy113/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        476 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.44     *
# *............................................................................*
# *Br  114 :Energy114 : Energy114/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  115 :Energy115 : Energy115/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  116 :Energy116 : Energy116/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  117 :Energy117 : Energy117/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  118 :Energy118 : Energy118/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        487 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.40     *
# *............................................................................*
# *Br  119 :Energy119 : Energy119/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  120 :Energy120 : Energy120/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        498 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.50     *
# *............................................................................*
# *Br  121 :Energy121 : Energy121/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        490 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.60     *
# *............................................................................*
# *Br  122 :Energy122 : Energy122/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        503 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 127.22     *
# *............................................................................*
# *Br  123 :Energy123 : Energy123/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  124 :Energy124 : Energy124/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        484 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.21     *
# *............................................................................*
# *Br  125 :Energy125 : Energy125/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        487 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.40     *
# *............................................................................*
# *Br  126 :Energy126 : Energy126/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  127 :Energy127 : Energy127/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        493 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.80     *
# *............................................................................*
# *Br  128 :Energy128 : Energy128/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        494 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.54     *
# *............................................................................*
# *Br  129 :Energy129 : Energy129/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        476 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.44     *
# *............................................................................*
# *Br  130 :Energy130 : Energy130/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.67     *
# *............................................................................*
# *Br  131 :Energy131 : Energy131/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        502 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 127.47     *
# *............................................................................*
# *Br  132 :Energy132 : Energy132/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        476 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.44     *
# *............................................................................*
# *Br  133 :Energy133 : Energy133/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  134 :Energy134 : Energy134/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        480 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.32     *
# *............................................................................*
# *Br  135 :Energy135 : Energy135/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        480 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.32     *
# *............................................................................*
# *Br  136 :Energy136 : Energy136/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        494 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.54     *
# *............................................................................*
# *Br  137 :Energy137 : Energy137/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        480 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.32     *
# *............................................................................*
# *Br  138 :Energy138 : Energy138/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        484 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.21     *
# *............................................................................*
# *Br  139 :Energy139 : Energy139/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        480 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.32     *
# *............................................................................*
# *Br  140 :Energy140 : Energy140/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  141 :Energy141 : Energy141/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  142 :Energy142 : Energy142/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        493 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.80     *
# *............................................................................*
# *Br  143 :Energy143 : Energy143/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        499 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.24     *
# *............................................................................*
# *Br  144 :Energy144 : Energy144/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  145 :Energy145 : Energy145/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  146 :Energy146 : Energy146/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  147 :Energy147 : Energy147/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  148 :Energy148 : Energy148/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.49     *
# *............................................................................*
# *Br  149 :Energy149 : Energy149/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.49     *
# *............................................................................*
# *Br  150 :Energy150 : Energy150/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        485 *
# ...
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.44     *
# *............................................................................*
# *Br  974 :Energy974 : Energy974/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  975 :Energy975 : Energy975/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        488 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.13     *
# *............................................................................*
# *Br  976 :Energy976 : Energy976/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  977 :Energy977 : Energy977/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        512 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 124.98     *
# *............................................................................*
# *Br  978 :Energy978 : Energy978/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        484 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.21     *
# *............................................................................*
# *Br  979 :Energy979 : Energy979/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.76     *
# *............................................................................*
# *Br  980 :Energy980 : Energy980/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  981 :Energy981 : Energy981/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        491 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.33     *
# *............................................................................*
# *Br  982 :Energy982 : Energy982/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.67     *
# *............................................................................*
# *Br  983 :Energy983 : Energy983/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.67     *
# *............................................................................*
# *Br  984 :Energy984 : Energy984/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.49     *
# *............................................................................*
# *Br  985 :Energy985 : Energy985/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        501 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 127.73     *
# *............................................................................*
# *Br  986 :Energy986 : Energy986/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.49     *
# *............................................................................*
# *Br  987 :Energy987 : Energy987/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  988 :Energy988 : Energy988/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        477 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.16     *
# *............................................................................*
# *Br  989 :Energy989 : Energy989/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        493 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.80     *
# *............................................................................*
# *Br  990 :Energy990 : Energy990/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  991 :Energy991 : Energy991/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  992 :Energy992 : Energy992/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        495 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.28     *
# *............................................................................*
# *Br  993 :Energy993 : Energy993/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  994 :Energy994 : Energy994/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  995 :Energy995 : Energy995/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        510 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 125.47     *
# *............................................................................*
# *Br  996 :Energy996 : Energy996/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.49     *
# *............................................................................*
# *Br  997 :Energy997 : Energy997/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br  998 :Energy998 : Energy998/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        473 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 135.29     *
# *............................................................................*
# *Br  999 :Energy999 : Energy999/F                                            *
# *Entries :    20000 : Total  Size=      80845 bytes  File Size  =        466 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 137.32     *
# *............................................................................*
# *Br 1000 :Energy1000 : Energy1000/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        479 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.60     *
# *............................................................................*
# *Br 1001 :Energy1001 : Energy1001/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        475 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.72     *
# *............................................................................*
# *Br 1002 :Energy1002 : Energy1002/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        485 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.95     *
# *............................................................................*
# *Br 1003 :Energy1003 : Energy1003/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        482 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.77     *
# *............................................................................*
# *Br 1004 :Energy1004 : Energy1004/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        483 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 132.49     *
# *............................................................................*
# *Br 1005 :Energy1005 : Energy1005/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        500 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 127.99     *
# *............................................................................*
# *Br 1006 :Energy1006 : Energy1006/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.67     *
# *............................................................................*
# *Br 1007 :Energy1007 : Energy1007/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        475 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 134.72     *
# *............................................................................*
# *Br 1008 :Energy1008 : Energy1008/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        468 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 136.74     *
# *............................................................................*
# *Br 1009 :Energy1009 : Energy1009/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        478 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 133.88     *
# *............................................................................*
# *Br 1010 :Energy1010 : Energy1010/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        497 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.76     *
# *............................................................................*
# *Br 1011 :Energy1011 : Energy1011/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        496 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 129.02     *
# *............................................................................*
# *Br 1012 :Energy1012 : Energy1012/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        497 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 128.76     *
# *............................................................................*
# *Br 1013 :Energy1013 : Energy1013/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        468 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 136.74     *
# *............................................................................*
# *Br 1014 :Energy1014 : Energy1014/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        487 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.40     *
# *............................................................................*
# *Br 1015 :Energy1015 : Energy1015/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        468 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 136.74     *
# *............................................................................*
# *Br 1016 :Energy1016 : Energy1016/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        503 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 127.22     *
# *............................................................................*
# *Br 1017 :Energy1017 : Energy1017/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        515 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 124.26     *
# *............................................................................*
# *Br 1018 :Energy1018 : Energy1018/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        486 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.67     *
# *............................................................................*
# *Br 1019 :Energy1019 : Energy1019/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        491 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 130.33     *
# *............................................................................*
# *Br 1020 :Energy1020 : Energy1020/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        506 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 126.47     *
# *............................................................................*
# *Br 1021 :Energy1021 : Energy1021/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        488 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 131.14     *
# *............................................................................*
# *Br 1022 :Energy1022 : Energy1022/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        520 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 123.07     *
# *............................................................................*
# *Br 1023 :Energy1023 : Energy1023/F                                          *
# *Entries :    20000 : Total  Size=      80853 bytes  File Size  =        500 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression= 127.99     *
# *............................................................................*

# %%
loader = ROOT.TMVA.DataLoader("dataset")

### global event weights per tree (see below for setting event-wise weights)
signalWeight     = 1.0
backgroundWeight = 1.0
   
### You can add an arbitrary number of signal or background trees
loader.AddSignalTree    ( signalTree,     signalWeight     )
loader.AddBackgroundTree( backgroundTree, backgroundWeight )

imgSize = 8 * 8; 
for  i in range(0,imgSize):
    varName = "Energy"+str(i)
    loader.AddVariable(varName,'F');
# Out:
# DataSetInfo              : [dataset] : Added class "Signal"
#                          : Add Tree sig_tree of type Signal with 20000 events
# DataSetInfo              : [dataset] : Added class "Background"
#                          : Add Tree bkg_tree of type Background with 20000 events

# %% [markdown]
# ## Setup Dataset(s)
#
# Define input data file and signal and background trees

# %%
## Apply additional cuts on the signal and background samples (can be different)
mycuts = ROOT.TCut("")   ## for example: TCut mycuts = "abs(var1)<0.5 && abs(var2-0.5)<1";
mycutb = ROOT.TCut("")   ## for example: TCut mycutb = "abs(var1)<0.5";


loader.PrepareTrainingAndTestTree( mycuts, mycutb,
                                  "nTrain_Signal=5000:nTrain_Background=5000:SplitMode=Random:"
                                   "NormMode=NumEvents:!V" )

# %% [markdown]
# # Booking Methods
#
# Here we book the TMVA methods. We book a DNN and a CNN

# %% [markdown]
# #### Booking Deep Neural Network
#
# Here we book the new DNN of TMVA. If using master version you can use the new DL method

# %%
inputLayoutString = "InputLayout=1|1|1024"; 
batchLayoutString= "BatchLayout=1|32|1024";
layoutString = ("Layout=DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|1|LINEAR")

training1  = "Optimizer=ADAM,LearningRate=1e-3,Momentum=0.,Regularization=None,WeightDecay=1e-4,"
training1 += "DropConfig=0.+0.+0.+0.,MaxEpochs=30,ConvergenceSteps=10,BatchSize=32,TestRepetitions=1"
trainingStrategyString = "TrainingStrategy=" + training1


dnnOptions = "!H:V:ErrorStrategy=CROSSENTROPY:VarTransform=None:WeightInitialization=XAVIER::Architecture=CPU"

dnnOptions +=  ":" + inputLayoutString
dnnOptions +=  ":" + batchLayoutString
dnnOptions +=  ":" + layoutString
dnnOptions +=  ":" + trainingStrategyString

#we can now book the method
              
factory.BookMethod(loader, ROOT.TMVA.Types.kDL, "DL_DENSE", dnnOptions)
# Out:
# <ROOT.TMVA::MethodDL object ("DL_DENSE") at 0x9504350>
# Factory                  : Booking method: DL_DENSE
#                          :
#                          : Parsing option string:
#                          : ... "!H:V:ErrorStrategy=CROSSENTROPY:VarTransform=G:WeightInitialization=XAVIER::Architecture=CPU:InputLayout=1|1|1024:BatchLayout=1|32|1024:Layout=DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|1|LINEAR:TrainingStrategy=Optimizer=ADAM,LearningRate=1e-3,Momentum=0.,Regularization=None,WeightDecay=1e-4,DropConfig=0.+0.+0.+0.,MaxEpochs=30,ConvergenceSteps=10,BatchSize=32,TestRepetitions=1"
#                          : The following options are set:
#                          : - By User:
#                          :     <none>
#                          : - Default:
#                          :     Boost_num: "0" [Number of times the classifier will be boosted]
#                          : Parsing option string:
#                          : ... "!H:V:ErrorStrategy=CROSSENTROPY:VarTransform=G:WeightInitialization=XAVIER::Architecture=CPU:InputLayout=1|1|1024:BatchLayout=1|32|1024:Layout=DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|1|LINEAR:TrainingStrategy=Optimizer=ADAM,LearningRate=1e-3,Momentum=0.,Regularization=None,WeightDecay=1e-4,DropConfig=0.+0.+0.+0.,MaxEpochs=30,ConvergenceSteps=10,BatchSize=32,TestRepetitions=1"
#                          : The following options are set:
#                          : - By User:
#                          :     V: "True" [Verbose output (short form of "VerbosityLevel" below - overrides the latter one)]
#                          :     VarTransform: "G" [List of variable transformations performed before training, e.g., "D_Background,P_Signal,G,N_AllClasses" for: "Decorrelation, PCA-transformation, Gaussianisation, Normalisation, each for the given class of events ('AllClasses' denotes all events of all classes, if no class indication is given, 'All' is assumed)"]
#                          :     H: "False" [Print method-specific help message]
#                          :     InputLayout: "1|1|1024" [The Layout of the input]
#                          :     BatchLayout: "1|32|1024" [The Layout of the batch]
#                          :     Layout: "DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|64|TANH,DENSE|1|LINEAR" [Layout of the network.]
#                          :     ErrorStrategy: "CROSSENTROPY" [Loss function: Mean squared error (regression) or cross entropy (binary classification).]
#                          :     WeightInitialization: "XAVIER" [Weight initialization strategy]
#                          :     Architecture: "CPU" [Which architecture to perform the training on.]
#                          :     TrainingStrategy: "Optimizer=ADAM,LearningRate=1e-3,Momentum=0.,Regularization=None,WeightDecay=1e-4,DropConfig=0.+0.+0.+0.,MaxEpochs=30,ConvergenceSteps=10,BatchSize=32,TestRepetitions=1" [Defines the training strategies.]
#                          : - Default:
#                          :     VerbosityLevel: "Default" [Verbosity level]
#                          :     CreateMVAPdfs: "False" [Create PDFs for classifier outputs (signal and background)]
#                          :     IgnoreNegWeightsInTraining: "False" [Events with negative weights are ignored in the training (but are included for testing and performance evaluation)]
#                          :     RandomSeed: "0" [Random seed used for weight initialization and batch shuffling]
# DL_DENSE                 : [dataset] : Create Transformation "G" with events from all classes.
#                          :
#                          : Transformation, Variable selection :
#                          : Input : variable 'Energy0' <---> Output : variable 'Energy0'
#                          : Input : variable 'Energy1' <---> Output : variable 'Energy1'
#                          : Input : variable 'Energy2' <---> Output : variable 'Energy2'
#                          : Input : variable 'Energy3' <---> Output : variable 'Energy3'
#                          : Input : variable 'Energy4' <---> Output : variable 'Energy4'
#                          : Input : variable 'Energy5' <---> Output : variable 'Energy5'
#                          : Input : variable 'Energy6' <---> Output : variable 'Energy6'
#                          : Input : variable 'Energy7' <---> Output : variable 'Energy7'
#                          : Input : variable 'Energy8' <---> Output : variable 'Energy8'
#                          : Input : variable 'Energy9' <---> Output : variable 'Energy9'
#                          : Input : variable 'Energy10' <---> Output : variable 'Energy10'
#                          : Input : variable 'Energy11' <---> Output : variable 'Energy11'
#                          : Input : variable 'Energy12' <---> Output : variable 'Energy12'
#                          : Input : variable 'Energy13' <---> Output : variable 'Energy13'
#                          : Input : variable 'Energy14' <---> Output : variable 'Energy14'
#                          : Input : variable 'Energy15' <---> Output : variable 'Energy15'
#                          : Input : variable 'Energy16' <---> Output : variable 'Energy16'
#                          : Input : variable 'Energy17' <---> Output : variable 'Energy17'
#                          : Input : variable 'Energy18' <---> Output : variable 'Energy18'
#                          : Input : variable 'Energy19' <---> Output : variable 'Energy19'
#                          : Input : variable 'Energy20' <---> Output : variable 'Energy20'
#                          : Input : variable 'Energy21' <---> Output : variable 'Energy21'
#                          : Input : variable 'Energy22' <---> Output : variable 'Energy22'
#                          : Input : variable 'Energy23' <---> Output : variable 'Energy23'
#                          : Input : variable 'Energy24' <---> Output : variable 'Energy24'
#                          : Input : variable 'Energy25' <---> Output : variable 'Energy25'
#                          : Input : variable 'Energy26' <---> Output : variable 'Energy26'
#                          : Input : variable 'Energy27' <---> Output : variable 'Energy27'
#                          : Input : variable 'Energy28' <---> Output : variable 'Energy28'
#                          : Input : variable 'Energy29' <---> Output : variable 'Energy29'
#                          : Input : variable 'Energy30' <---> Output : variable 'Energy30'
#                          : Input : variable 'Energy31' <---> Output : variable 'Energy31'
#                          : Input : variable 'Energy32' <---> Output : variable 'Energy32'
#                          : Input : variable 'Energy33' <---> Output : variable 'Energy33'
#                          : Input : variable 'Energy34' <---> Output : variable 'Energy34'
#                          : Input : variable 'Energy35' <---> Output : variable 'Energy35'
#                          : Input : variable 'Energy36' <---> Output : variable 'Energy36'
#                          : Input : variable 'Energy37' <---> Output : variable 'Energy37'
#                          : Input : variable 'Energy38' <---> Output : variable 'Energy38'
#                          : Input : variable 'Energy39' <---> Output : variable 'Energy39'
#                          : Input : variable 'Energy40' <---> Output : variable 'Energy40'
#                          : Input : variable 'Energy41' <---> Output : variable 'Energy41'
#                          : Input : variable 'Energy42' <---> Output : variable 'Energy42'
#                          : Input : variable 'Energy43' <---> Output : variable 'Energy43'
#                          : Input : variable 'Energy44' <---> Output : variable 'Energy44'
#                          : Input : variable 'Energy45' <---> Output : variable 'Energy45'
#                          : Input : variable 'Energy46' <---> Output : variable 'Energy46'
#                          : Input : variable 'Energy47' <---> Output : variable 'Energy47'
#                          : Input : variable 'Energy48' <---> Output : variable 'Energy48'
#                          : Input : variable 'Energy49' <---> Output : variable 'Energy49'
#                          : Input : variable 'Energy50' <---> Output : variable 'Energy50'
#                          : Input : variable 'Energy51' <---> Output : variable 'Energy51'
#                          : Input : variable 'Energy52' <---> Output : variable 'Energy52'
#                          : Input : variable 'Energy53' <---> Output : variable 'Energy53'
#                          : Input : variable 'Energy54' <---> Output : variable 'Energy54'
#                          : Input : variable 'Energy55' <---> Output : variable 'Energy55'
#                          : Input : variable 'Energy56' <---> Output : variable 'Energy56'
#                          : Input : variable 'Energy57' <---> Output : variable 'Energy57'
#                          : Input : variable 'Energy58' <---> Output : variable 'Energy58'
#                          : Input : variable 'Energy59' <---> Output : variable 'Energy59'
#                          : Input : variable 'Energy60' <---> Output : variable 'Energy60'
#                          : Input : variable 'Energy61' <---> Output : variable 'Energy61'
#                          : Input : variable 'Energy62' <---> Output : variable 'Energy62'
#                          : Input : variable 'Energy63' <---> Output : variable 'Energy63'
#                          : Will use now the CPU architecture !

# %% [markdown]
# ### Book Convolutional Neural Network in TMVA

# %%
#input layout 
inputLayoutString = "InputLayout=1|32|32"
                                                                                                
## Batch Layout                                                                                                                                     
batchLayoutString = "BatchLayout=32|1|1024"
                                                   

layoutString = ("Layout=CONV|10|3|3|1|1|1|1|RELU,CONV|10|3|3|1|1|1|1|RELU,MAXPOOL|2|2|1|1,"
            "RESHAPE|FLAT,DENSE|64|TANH,DENSE|1|LINEAR")
                                                                                                                                              


##Training strategies.                                                                                                                          
training1 = ("LearningRate=1e-3,Momentum=0.9,Repetitions=1,"
                     "ConvergenceSteps=10,BatchSize=32,TestRepetitions=1,"
                     "MaxEpochs=20,WeightDecay=1e-4,Regularization=None,"
                     "Optimizer=ADAM,DropConfig=0.0+0.0+0.0+0.0")

trainingStrategyString = "TrainingStrategy=" + training1
    
## General Options.                                                                                                                              
cnnOptions = ("!H:V:ErrorStrategy=CROSSENTROPY:VarTransform=None:"
                       "WeightInitialization=XAVIERUNIFORM");

cnnOptions +=  ":" + inputLayoutString
cnnOptions +=  ":" + batchLayoutString
cnnOptions +=  ":" + layoutString
cnnOptions +=  ":" + trainingStrategyString
cnnOptions +=  ":Architecture=CPU"

##book CNN
factory.BookMethod(loader, ROOT.TMVA.Types.kDL, "DL_CNN", cnnOptions);

# %% [markdown]
# ### Book Convolutional Neural Network in Keras using a generated model

# %%
## to use tensorflow backend
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
from keras.models import Sequential
from keras.optimizers import Adam, SGD
#from keras.initializers import TruncatedNormal
#from keras import initializations
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Reshape
#from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(Reshape((32,32, 1), input_shape=(1024,)))
model.add(Conv2D(10, kernel_size=(3,3), kernel_initializer='glorot_normal', activation='relu', padding='same' ) )
model.add(Conv2D(10, kernel_size=(3,3), kernel_initializer='glorot_normal', activation='relu', padding='same' ) )
#stride for maxpool is equal to pool size
model.add(MaxPooling2D(pool_size=(2, 2) ))
#model.add(Conv2D(10, activation='relu', kernel_size=(3,3), padding='same', kernel_initializer='glorot_normal'))
#model.add(Conv2D(10, activation='relu', kernel_size=(3,3), padding='same', kernel_initializer='glorot_normal'))
#model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
#model.add(Dropout(0.2))
model.add(Dense(2, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.001), metrics=['accuracy'])
model.save('model_cnn.h5')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 10)        100
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 10)        910
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 10)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2560)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                163904
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 165,044
# Trainable params: 165,044
# Non-trainable params: 0
# _________________________________________________________________
# 2018-09-20 13:04:38.632711: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA

# %%
kerasOption = ("H:!V:VarTransform=None:FilenameModel=model_cnn.h5:"
               "FilenameTrainedModel=trained_model_cnn.h5:NumEpochs=20:BatchSize=32")
factory.BookMethod(loader, ROOT.TMVA.Types.kPyKeras,"PyKeras",kerasOption)
# Out:
# <ROOT.TMVA::MethodPyKeras object ("PyKeras") at 0xd4b7c00>
# Factory                  : Booking method: PyKeras
#                          :
#                          : Load model from file: model_cnn.h5

# %% [markdown]
# ## Train Methods

# %%
##retrieve data before to remove output during data retrieval
ROOT.TMVA.MsgLogger.InhibitOutput()
dloader.GetDefaultDataSetInfo().GetDataSet()
ROOT.TMVA.MsgLogger.EnableOutput()

# %%
factory.TrainAllMethods()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-13-4bb1800441f7> in <module>()
# ----> 1 factory.TrainAllMethods()
#
# Exception: void TMVA::Factory::TrainAllMethods() =>
#     vector::_M_range_check: __n (which is 64) >= this->size() (which is 64) (C++ exception of type out_of_range)
# Factory                  : Train all methods
# DataSetFactory           : [dataset] : Number of events in input trees
#                          :
#                          :
#                          : Number of training and testing events
#                          : ---------------------------------------------------------------------------
#                          : Signal     -- training events            : 5000
#                          : Signal     -- testing events             : 15000
#                          : Signal     -- training and testing events: 20000
#                          : Background -- training events            : 5000
#                          : Background -- testing events             : 15000
#                          : Background -- training and testing events: 20000
#                          :
# <WARNING>                : Dataset[dataset] : Variable Energy2 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy3 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy4 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy5 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy12 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy14 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy15 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy19 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy27 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy28 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy29 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy37 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy40 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy52 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy53 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy55 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy60 is constant. Please remove the variable.
# <WARNING>                : Dataset[dataset] : Variable Energy62 is constant. Please remove the variable.
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 1) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 2) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 3) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 4) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 5) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 6) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 7) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 8) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 9) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 10) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 11) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 12) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 13) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 14) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 15) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 16) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 17) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 18) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 19) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 20) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 21) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 22) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 23) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 24) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 25) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 26) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 27) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 28) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 29) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 30) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 31) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 32) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 33) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 34) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 35) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 36) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 37) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 38) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 39) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 40) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 41) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 42) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 43) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 44) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 45) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 46) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 47) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 48) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 49) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 50) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 51) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 52) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 53) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 54) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 55) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 56) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 57) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 58) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 59) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 60) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 61) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 62) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (0, 63) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 0) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 2) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 3) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 4) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 5) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 6) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 11) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 12) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 13) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 14) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 15) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 16) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 17) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 19) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 20) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 22) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 27) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 28) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 29) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 30) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 31) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 35) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 36) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 37) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 40) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 41) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 46) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 47) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 50) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 51) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 52) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 53) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 55) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 57) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 60) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 62) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (1, 63) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 0) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 1) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 3) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 4) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 5) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 6) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 7) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 8) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 9) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 10) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 11) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 12) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 13) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 14) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 15) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 16) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 17) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 18) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 19) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 20) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 21) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 22) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 23) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 24) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 25) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 26) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 27) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 28) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 29) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 30) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 31) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 32) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 33) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 34) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 35) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 36) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 37) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 38) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 39) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 40) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 41) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 42) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 43) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 44) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 45) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 46) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 47) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 48) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 49) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 50) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 51) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 52) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 53) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 54) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 55) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 56) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 57) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 58) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 59) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 60) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 61) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 62) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (2, 63) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 0) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 1) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 2) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 4) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 5) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 6) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 7) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 8) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 9) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 10) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 11) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 12) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 13) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 14) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 15) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 16) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 17) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 18) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 19) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 20) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 21) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 22) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 23) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 24) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 25) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 26) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 27) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 28) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 29) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 30) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 31) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 32) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 33) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 34) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 35) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 36) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 37) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 38) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 39) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 40) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 41) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 42) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 43) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 44) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 45) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 46) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 47) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 48) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 49) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 50) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 51) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 52) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 53) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 54) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 55) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 56) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 57) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 58) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 59) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 60) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 61) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 62) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (3, 63) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 0) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 1) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 2) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 3) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 5) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 6) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 7) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 8) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 9) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 10) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 11) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 12) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 13) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 14) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 15) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 16) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 17) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 18) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 19) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 20) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 21) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 22) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 23) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 24) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 25) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 26) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 27) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 28) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 29) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 30) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 31) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 32) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 33) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 34) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 35) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 36) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 37) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 38) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 39) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 40) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 41) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 42) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 43) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 44) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 45) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 46) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 47) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 48) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 49) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 50) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 51) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 52) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 53) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 54) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 55) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 56) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 57) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 58) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 59) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 60) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 61) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 62) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (4, 63) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 0) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 1) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 2) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 3) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 4) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 6) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 7) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 8) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 9) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 10) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 11) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 12) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 13) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 14) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 15) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 16) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 17) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 18) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 19) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 20) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 21) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 22) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 23) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 24) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 25) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 26) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 27) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 28) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 29) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 30) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 31) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 32) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 33) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 34) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 35) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 36) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 37) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 38) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 39) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 40) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 41) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 42) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 43) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 44) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 45) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 46) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 47) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 48) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 49) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 50) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 51) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 52) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 53) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 54) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 55) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 56) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 57) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 58) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 59) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 60) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 61) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 62) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (5, 63) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 0) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 1) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 2) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 3) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 4) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 5) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 7) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 8) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 9) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 10) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 11) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 12) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 13) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 14) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 15) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 16) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 17) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 18) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 19) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 20) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 21) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 22) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 23) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 24) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 25) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 26) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 27) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 28) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 29) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 30) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 31) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 32) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 33) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 34) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 35) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 36) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 37) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 38) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 39) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 40) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 41) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 42) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 43) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 44) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 45) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 46) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 47) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 48) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 49) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 50) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 51) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 52) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 53) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 54) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 55) = 0
# <WARNING>                : Dataset[Default] : <GetCorrelationMatrix> Zero variances for variables (6, 56) = 0
# ...
#                          : Energy41:    -3.1609   0.088921   [    -3.1618     5.7307 ]
#                          : Energy42:    -3.1009   0.088321   [    -3.1018     5.7307 ]
#                          : Energy43:   -0.42820   0.087109   [   -0.42943     5.7307 ]
#                          : Energy44:   -0.42919   0.050297   [   -0.42960     5.7307 ]
#                          : Energy45:    -3.1741   0.091884   [    -3.1751     5.7307 ]
#                          : Energy46:    -3.0748   0.050839   [    -3.0751     5.7307 ]
#                          : Energy47:    -3.0391    0.11429   [    -5.7307     5.7307 ]
#                          : Energy48:    -3.1397    0.13551   [    -3.1418     5.7307 ]
#                          : Energy49:   -0.42946 2.8066e-07   [   -0.42946   -0.42946 ]
#                          : Energy50:   -0.42960   0.039060   [   -0.42989     5.7307 ]
#                          : Energy51:   -0.42824   0.087110   [   -0.42947     5.7307 ]
#                          : Energy52:    -5.7307     0.0000   [    -5.7307    -5.7307 ]
#                          : Energy53:    -5.7307     0.0000   [    -5.7307    -5.7307 ]
#                          : Energy54:    -3.1103   0.072189   [    -3.1109     5.7307 ]
#                          : Energy55:    -5.7307     0.0000   [    -5.7307    -5.7307 ]
#                          : Energy56:    -3.0039   0.087350   [    -3.0047     5.7307 ]
#                          : Energy57:   -0.42964   0.019799   [   -0.42979     2.7386 ]
#                          : Energy58:   -0.42925   0.039129   [   -0.42962     5.7307 ]
#                          : Energy59:    -3.0727    0.10166   [    -3.0738     5.7307 ]
#                          : Energy60:    -5.7307     0.0000   [    -5.7307    -5.7307 ]
#                          : Energy61:   -0.42935   0.061988   [    -5.7307     5.7307 ]
#                          : Energy62:    -5.7307     0.0000   [    -5.7307    -5.7307 ]
#                          : Energy63:    -3.1608   0.088920   [    -3.1617     5.7307 ]
#                          : -----------------------------------------------------------
#                          : *****   Deep Learning Network *****
# DEEP NEURAL NETWORK:   Depth = 5  Input = ( 1, 1, 1024 )  Batch size = 32  Loss function = C
# 	Layer 0	 DENSE Layer: 	  ( Input = 1024 , Width = 64 ) 	Output = ( 1 , 32 , 64 ) 	 Activation Function = Tanh
# 	Layer 1	 DENSE Layer: 	  ( Input = 64 , Width = 64 ) 	Output = ( 1 , 32 , 64 ) 	 Activation Function = Tanh
# 	Layer 2	 DENSE Layer: 	  ( Input = 64 , Width = 64 ) 	Output = ( 1 , 32 , 64 ) 	 Activation Function = Tanh
# 	Layer 3	 DENSE Layer: 	  ( Input = 64 , Width = 64 ) 	Output = ( 1 , 32 , 64 ) 	 Activation Function = Tanh
# 	Layer 4	 DENSE Layer: 	  ( Input = 64 , Width = 1 ) 	Output = ( 1 , 32 , 1 ) 	 Activation Function = Identity
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2
# Error in <TH1F::Smooth>: Smooth only supported for histograms with >= 3 bins. Nbins = 2

# %% [markdown]
# ## Test and Evaluate Methods

# %%
factory.TestAllMethods()

# %%
ROOT.TMVA.MsgLogger.InhibitOutput()
factory.EvaluateAllMethods()
ROOT.TMVA.MsgLogger.EnableOutput()

# %% [markdown]
# ## Plot ROC Curve
# We enable JavaScript visualisation for the plots

# %%
//%jsroot on

# %%
c1 = factory.GetROCCurve(loader);
c1->Draw();

# %%
// close outputfile to save output file
outputFile->Close();
