// %% [markdown]
// ### Plot of ROC Curve
//
// This macro uses function in the TMVAGui libraries to plot efficiencies and purity curves and significances separtly for the various classifiers

// %%
fileName = "TMVA_ClassificationOutput.root";
dataset = "dataset";

// %%
TMVA::mvaeffs(dataset,fileName);
// Out:
// --- Opening root file TMVA_ClassificationOutput.root in read mode
// Error in <TGNumberEntry::TGNumberEntry>: arrow_up.xpm not found
// Error in <TGNumberEntry::TGNumberEntry>: arrow_down.xpm not found
// Error in <TGPictureButton::TGPictureButton>: pixmap not found for button 1
// Error in <TGPictureButton::TGPictureButton>: pixmap not found for button 2
// --- Found directory: Method_Likelihood
// --- Classifier: Likelihood
// --- Found directory: Method_LikelihoodKDE
// --- Classifier: LikelihoodKDE
// --- Found directory: Method_LD
// --- Classifier: LD
// --- Found directory: Method_Fisher
// --- Classifier: Fisher
// --- Found directory: Method_BDT
// --- Classifier: BDT
// --- Found directory: Method_MLP
// --- Classifier: MLP
// --- =====================================================================================================
// ---    Classifier   (  #signal, #backgr.)  Optimal-cut  S/sqrt(S+B)      NSig      NBkg   EffSig   EffBkg
// ...

// %%
%jsroot on

// %%
canvas1->Draw()
// Out:
// <div id="root_plot_1"
//      style="width: 596px; height: 440px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
canvas2->Draw();
// Out:
// <div id="root_plot_2"
//      style="width: 596px; height: 440px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
canvas3->Draw()
